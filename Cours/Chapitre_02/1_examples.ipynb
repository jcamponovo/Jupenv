# %%
# Permet de tout executer au lancement du notebook + conserver le notebook actif pendant 2h
from IPython.display import Javascript
Javascript("""
function repeter(){
IPython.notebook.kernel.execute("kernelsurvivor = 1");
}
// execute a = 1 en python toutes les 8 minutes pendant 2h
let timerId = setInterval(() => repeter(), 4800);
setTimeout(() => { clearInterval(timerId); alert('fin de cession'); }, 7200000);

// Supprimer la taille limite pour la sortie d'une cellule
IPython.OutputArea.prototype._should_scroll = function(lines) {
    return false;
};
IPython.notebook.kernel.execute("url = '" + window.location + "'");

// Exécuter toutes les cellule du notebook
    require(
        ['base/js/namespace', 'jquery'], 
        function(jupyter, $) {
            
                
                jupyter.actions.call('jupyter-notebook:run-all-cells-below');
                jupyter.actions.call('jupyter-notebook:save-notebook');

        }
    );""")

# %%
from ipywidgets import Button, HBox, Layout, VBox,Label, HTML,FileUpload
import os
import time


download_bou = Button(
    description='Save',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Save',
    icon='download' # (FontAwesome names without the `fa-` prefix)
)


upload_bou = FileUpload(
    description='zip',
    disabled=False,
    accept=".zip",
    multiple=False,
    tooltip='zip',
    icon='upload' # (FontAwesome names without the `fa-` prefix)

)

message = Label(
    value = "")

menu = HTML(
    value = "<a href = ../../apps/environnement.ipynb target = _blank>Menu</a>")
lien = HTML(
    value = "")

def zipToServer(b):
    lien.value = ""
    path = os.getcwd()
    os.chdir("/home/jovyan/")
    message.value = "decompression du fichier de sauvegarde"
    v = upload_bou.value
    
    with open(next(iter(upload_bou.value)), "w+b") as i:
        i.write(upload_bou.data[0])
    a = os.popen("""unzip -o {}""".format(next(iter(upload_bou.value))))
    m = ""
    for ligne in a:
        m += str(ligne)
    j = open("log_cadaver.txt","a")
    j.write("\n\n")
    j.write(m)
    j.close()
    os.chdir(path)
    message.value = "opération terminée avec succès. Cliquez sur le lien ci-dessous pour accéder au menu"
    lien.value = "<a href = ../../apps/environnement.ipynb target = _blank>Menu</a>"

def reset(b):
    lien.value = ""
    message.value = ""
    
def saveToAtrium(b):
    lien.value = ""
    Javascript("""jupyter.actions.call('jupyter-notebook:save-notebook');""")
    path = os.getcwd()
    os.chdir("/home/jovyan/")
    t = time.localtime()
    message.value = "création du fichier de sauvegarde"
    file = "nsipremiere{:4d}{:02d}{:02d}{:02d}{:02d}{:02d}.zip".format(t.tm_year,t.tm_mon,t.tm_mday,t.tm_hour,t.tm_min,t.tm_sec)
    a = os.popen("""zip -r {} Perso""".format(file))
    m = ""
    for ligne in a:
        m += str(ligne)
    j = open("log_cadaver.txt","a")
    j.write("\n\n")
    j.write(m)
    j.close()
    
    #j = open(".netrc","r")
    #data = j.readlines()
    #j.close()
    #data = data[1]
    #login = data.split(" ")[1].strip()
    
    #message.value = "upload du fichier de sauvegarde vers atrium"
    #j = open("datadav","w")
    #j.write("cd {}\ncd document_library\nput /home/jovyan/nsipremiere{:4d}{:02d}{:02d}{:02d}{:02d}{:02d}.zip\nexit".format(login,t.tm_year,t.tm_mon,t.tm_mday,t.tm_hour,t.tm_min,t.tm_sec))
    #j.close()
    #a = os.popen("""cadaver -r datadav https://www.atrium-sud.fr/webdav""")
    #m = ""
    #for ligne in a:
    #    m += str(ligne)
    #j = open("log_cadaver.txt","a")
    #j.write("\n\n")
    #j.write(m)
    #j.close()
    #if "succeeded" in m:
    #    message.value = "operation terminée avec succès"
    #else:
    #    message.value = m
    message.value = "Sauvegarde réalisée avec succès sur le serveur, cliquez sur le lien ci-dessous pour télécharger le fichier"
    lien.value = "<a href=../{} download>Télécharger sauvegarde</a>".format(file)
    
    os.chdir(path)

download_bou.on_click(saveToAtrium)
#upload_bou.observe(zipToServer, "data")
display(HBox([menu,download_bou]))
display(message)
display(lien)
# Out:
# ...
# Label(value='')
# HTML(value='')

# %% [markdown]
# Une chaîne de caractères (type str en python) est utilisée pour stocker du texte. Elle est délimitée par ', " ou """ en début et fin de chaîne

# %%
t = "aujourd'hui"
s = 'robert dit: "bonjour!"'
u = """robert dit: 
\"aujourd'hui c'est la rentrée!\""""

# %%
t
# Out:
# "aujourd'hui"

# %%
s
# Out:
# 'robert dit: "bonjour!"'

# %% [markdown]
# La délimitation par les triples guillemets permet d'écrire sur plusieurs lignes. On utilise \ comme caractère d'échapement c'est à dire pour considérer le caractère spécial suivant comme un caractère. Ici ce système est utilisé pour mettre des guillemets dans la chaîne de caractère.

# %%
print(u)
# Out:
# robert dit:
# "aujourd'hui c'est la rentrée!"

# %% [markdown]
# Un str est itérable c'est à dire que l'on peut appeler chacune des lettres avec son indice comme dans les listes. Les caractères sont indicés à partir de 0. On peut aussi utiliser des indices négatifs pour numéroter à partir de la fin.

# %%
t[1]
# Out:
# 'u'

# %%
t[-2]
# Out:
# 'l'

# %% [markdown]
# On peut aussi récupérer sa taille

# %%
len(t)
# Out:
# 11

# %% [markdown]
# Par contre, à la différence du type list, un str n'est **pas mutable**, c'est à dire qu'on ne peut pas changer la valeur stockée à un indice de la chaîne (on ne peut pas changer une lettre en gardant le même objet)

# %%
t[1] = 'o'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-ce8fb00a8d3c> in <module>()
# ----> 1 t[1] = 'o'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# Comme pour les listes, l'opérateur + réalise une concaténation.

# %%
t = "hello"
s = "world"
t + " " + s
# Out:
# 'hello world'

# %% [markdown]
# La syntaxe pour réaliser des slices est la même que pour les listes. t[debut:fin:pas], la fin etant exclue. On peut omettre le pas (par défaut sa valeur est 1), le début (par défaut le début de la chaîne si le pas est positif, la fin s'il est négatif) ou la fin (par défaut la fin de la chaîne si le pas est positif, le début s'il est négatif).

# %%
t[1:5]

# %% [markdown]
# On peut donc utiliser des slices pour obtenir une nouvelle chaîne de caractères avec quelques caractères modifiés

# %%
t[:1]+"o"+t[2:]

# %% [markdown]
# On peut itérer sur les lettres d'une chaîne de caractère

# %%
for lettre in t:
    print(lettre)

# %% [markdown]
# La conversion en liste nous donne la liste des caractères présents dans la chaîne. Chaque caractère estd e type str également.

# %%
lt = list(t)
lt
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
lt[1]= "o"
lt
# Out:
# ['h', 'o', 'l', 'l', 'o']

# %% [markdown]
# La méthode join permet de regrouper en un seul str un itérable composé de str. La chaîne indiquée au début est utilisée pour séparer les différents éléments.

# %%
"".join(lt)
# Out:
# 'hollo'

# %%
"*".join("star")
# Out:
# 's*t*a*r'

# %%
help("".join)
# Out:
# Help on built-in function join:
#
# join(iterable, /) method of builtins.str instance
#     Concatenate any number of strings.
#
#     The string whose method is called is inserted in between each given string.
#     The result is returned as a new string.
#
#     Example: '.'.join(['ab', 'pq', 'rs']) -> 'ab.pq.rs'

# %% [markdown]
# Les caractères \n et \r servent respectivement à revenir à la ligne et retourner en début de ligne. Un appui sur enter dans un fichier .txt provoque l'insertion de ces deux caractères sous windows (seulement \n sous linux)

# %% [markdown]
# La méthode strip permet de nettoyer une chaîne de caractères en supprimants les espaces au début et à la fin d ela chaîne ainsi que ces caractères \n et \r en début et en fin de chaîne.

# %%
t = "  hello\n\r"

# %%
t.strip()
# Out:
# 'hello'

# %% [markdown]
# La méthode split permet de séparer une chaîne de caractère en une liste de str à chaque fois que l'argument donné à split est rencontré.

# %%
"bonjour à tous".split(" ")
# Out:
# ['bonjour', 'à', 'tous']

# %%
help("".split)
# Out:
# Help on built-in function split:
#
# split(sep=None, maxsplit=-1) method of builtins.str instance
#     Return a list of the words in the string, using sep as the delimiter string.
#
#     sep
#       The delimiter according which to split the string.
#       None (the default value) means split according to any whitespace,
#       and discard empty strings from the result.
#     maxsplit
#       Maximum number of splits to do.
#       -1 (the default value) means no limit.

# %% [markdown]
# Enfin, la méthode replace permet de remplacer toutes les occurences d'une sous-chaîne dans un str par une autre sous-chaîne. Attention, un str est non mutable, cette méthode renvoie donc une nouvelle chaîne, la chaîne initiale n'est pas modifiée.

# %%
t = "hello world"
t
# Out:
# 'hello world'

# %%
t.replace("o","0")
# Out:
# 'hell0 w0rld'

# %%
t
# Out:
# 'hello world'

# %% [markdown]
# Bien d'autres méthodes et fonctions existent, n'hésitez pas à consulter [la documentation de python](https://docs.python.org/fr/3/library/string.html) ou à utiliser la commande help
